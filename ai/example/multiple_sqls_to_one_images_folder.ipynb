# %%
import glob
import os
import io
import sys
import shutil
import glob
import sqlite3
import numpy as np
import torch
import matplotlib.pyplot as plt
from pathlib import Path
from time import time
from PIL import Image, ImageFilter, ImageChops
import mediapy as media

# %%
# Delete working image, and create a new one
# !rm -rf working
# !mkdir working
# !mkdir working/tmp_input

file_paths = [
	"662B5822-D943-4826-B322-926A8C7645C1",
	"72763945-4493-4F65-9E8F-80D8F3D2CA20",
	"371467AC-1C97-4ECF-81CB-C4381F7CE73C",
	"0AC6D7F9-C85D-418C-A21C-5934530D9782",
	"4BE8D61F-93F4-42C3-9014-7CB0C6B090FB",
]

for file_i, file_path in enumerate(file_paths):
	connection = sqlite3.connect(f'./split_dbs/db_session_{file_path}.sqlite')

	# Get all data
	cursor = connection.cursor()
	cursor.execute("SELECT image_blob FROM maptodon_raw WHERE ROWID % 10 = 0")
	results = cursor.fetchall()

	# Process the search results
	image_hashes = {}
	if len(results) > 0:
		for i, row in enumerate(results):
			image_data = row[0]

			# Save to working directory
			image = Image.open(io.BytesIO(image_data))

			image.save(f"./working/tmp_input/image{file_i}_{i:05d}.png")
		print("Saved " + str(len(results)) + " images to working directory.")
	else:
		print("No results found.")

	# Close the database connection
	connection.close()
# Out:
# Saved 135 images to working directory.
# Saved 179 images to working directory.
# Saved 116 images to working directory.
# Saved 92 images to working directory.
# Saved 75 images to working directory.

# %%
from PIL import Image
import numpy as np
import os

def is_blurry(image, threshold):
    """
    Determine if the image is blurry using the variance of the Laplacian operator.
    :param image: The image as a numpy array.
    :param threshold: The threshold to determine if the image is blurry.
    :return: True if the image is blurry, False otherwise.
    """
    kernel = np.array([[0, -1, 0], [-1, 4, -1], [0, -1, 0]])
    laplacian = np.abs(np.convolve(image.flatten(), kernel.flatten(), 'same'))
    variance = np.var(laplacian)
    return variance < threshold

def delete_blurry_images(directory, threshold):
    """
    Delete all blurry images in the specified directory.
    :param directory: The directory where the images are stored.
    :param threshold: The threshold to determine if an image is blurry.
    """
    for filename in os.listdir(directory):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            file_path = os.path.join(directory, filename)
            image = Image.open(file_path).convert('L')  # convert image to grayscale
            image = np.array(image)
            
            if is_blurry(image, threshold):
                os.remove(file_path)
                print(f"Deleted {filename} as it was blurry.")

# Example usage:
# Set your own values for these variables
image_directory = "./working/tmp_input"
blur_threshold = 700  # Adjust the threshold as per your requirement

delete_blurry_images(image_directory, blur_threshold)
# Out:
# Deleted image2_00095.png as it was blurry.
# Deleted image2_00081.png as it was blurry.
# Deleted image2_00042.png as it was blurry.
# Deleted image1_00062.png as it was blurry.
# Deleted image1_00076.png as it was blurry.
# Deleted image4_00051.png as it was blurry.
# Deleted image4_00045.png as it was blurry.
# Deleted image3_00009.png as it was blurry.
# Deleted image1_00116.png as it was blurry.
# Deleted image3_00035.png as it was blurry.
# Deleted image0_00029.png as it was blurry.
# Deleted image0_00028.png as it was blurry.
# Deleted image3_00034.png as it was blurry.
# Deleted image1_00103.png as it was blurry.
# Deleted image3_00008.png as it was blurry.
# Deleted image1_00117.png as it was blurry.
# Deleted image4_00044.png as it was blurry.
# Deleted image4_00050.png as it was blurry.
# Deleted image1_00077.png as it was blurry.
# Deleted image1_00063.png as it was blurry.
# Deleted image2_00043.png as it was blurry.
# Deleted image2_00080.png as it was blurry.
# Deleted image2_00041.png as it was blurry.
# Deleted image2_00069.png as it was blurry.
# Deleted image1_00075.png as it was blurry.
# Deleted image1_00061.png as it was blurry.
# Deleted image4_00046.png as it was blurry.
# Deleted image4_00052.png as it was blurry.
# Deleted image1_00115.png as it was blurry.
# Deleted image1_00129.png as it was blurry.
# Deleted image3_00036.png as it was blurry.
# Deleted image2_00109.png as it was blurry.
# Deleted image1_00128.png as it was blurry.
# Deleted image3_00037.png as it was blurry.
# Deleted image1_00114.png as it was blurry.
# Deleted image4_00053.png as it was blurry.
# Deleted image4_00047.png as it was blurry.
# Deleted image1_00048.png as it was blurry.
# Deleted image1_00060.png as it was blurry.
# Deleted image1_00074.png as it was blurry.
# Deleted image2_00068.png as it was blurry.
# Deleted image2_00040.png as it was blurry.
# Deleted image2_00083.png as it was blurry.
# Deleted image2_00087.png as it was blurry.
# Deleted image2_00078.png as it was blurry.
# Deleted image2_00044.png as it was blurry.
# Deleted image2_00050.png as it was blurry.
# Deleted image1_00058.png as it was blurry.
# Deleted image1_00070.png as it was blurry.
# Deleted image1_00064.png as it was blurry.
# Deleted image4_00043.png as it was blurry.
# Deleted image4_00057.png as it was blurry.
# Deleted image3_00027.png as it was blurry.
# Deleted image3_00033.png as it was blurry.
# Deleted image1_00104.png as it was blurry.
# Deleted image1_00110.png as it was blurry.
# Deleted image1_00111.png as it was blurry.
# Deleted image3_00032.png as it was blurry.
# Deleted image3_00026.png as it was blurry.
# Deleted image4_00056.png as it was blurry.
# Deleted image4_00042.png as it was blurry.
# Deleted image1_00065.png as it was blurry.
# Deleted image1_00071.png as it was blurry.
# Deleted image1_00059.png as it was blurry.
# Deleted image2_00051.png as it was blurry.
# Deleted image2_00045.png as it was blurry.
# Deleted image2_00079.png as it was blurry.
# Deleted image2_00092.png as it was blurry.
# Deleted image2_00086.png as it was blurry.
# Deleted image2_00090.png as it was blurry.
# Deleted image2_00084.png as it was blurry.
# Deleted image2_00047.png as it was blurry.
# Deleted image1_00067.png as it was blurry.
# Deleted image1_00073.png as it was blurry.
# Deleted image4_00054.png as it was blurry.
# Deleted image4_00040.png as it was blurry.
# Deleted image4_00068.png as it was blurry.
# Deleted image3_00030.png as it was blurry.
# Deleted image1_00113.png as it was blurry.
# Deleted image0_00038.png as it was blurry.
# Deleted image0_00039.png as it was blurry.
# Deleted image1_00112.png as it was blurry.
# Deleted image3_00031.png as it was blurry.
# Deleted image4_00069.png as it was blurry.
# Deleted image4_00041.png as it was blurry.
# Deleted image4_00055.png as it was blurry.
# Deleted image1_00072.png as it was blurry.
# Deleted image1_00066.png as it was blurry.
# Deleted image2_00046.png as it was blurry.
# Deleted image2_00085.png as it was blurry.
# Deleted image2_00091.png as it was blurry.
# Deleted image2_00035.png as it was blurry.
# Deleted image2_00021.png as it was blurry.
# Deleted image0_00116.png as it was blurry.
# Deleted image0_00102.png as it was blurry.
# Deleted image1_00015.png as it was blurry.
# Deleted image1_00029.png as it was blurry.
# Deleted image4_00032.png as it was blurry.
# Deleted image4_00026.png as it was blurry.
# Deleted image3_00081.png as it was blurry.
# Deleted image1_00161.png as it was blurry.
# Deleted image3_00056.png as it was blurry.
# Deleted image3_00042.png as it was blurry.
# Deleted image0_00089.png as it was blurry.
# Deleted image0_00077.png as it was blurry.
# Deleted image0_00088.png as it was blurry.
# Deleted image3_00043.png as it was blurry.
# Deleted image3_00057.png as it was blurry.
# Deleted image1_00160.png as it was blurry.
# Deleted image4_00027.png as it was blurry.
# Deleted image4_00033.png as it was blurry.
# Deleted image1_00028.png as it was blurry.
# Deleted image1_00014.png as it was blurry.
# Deleted image0_00103.png as it was blurry.
# Deleted image0_00117.png as it was blurry.
# Deleted image2_00020.png as it was blurry.
# Deleted image2_00034.png as it was blurry.
# Deleted image2_00022.png as it was blurry.
# Deleted image0_00129.png as it was blurry.
# Deleted image2_00036.png as it was blurry.
# Deleted image0_00101.png as it was blurry.
# Deleted image0_00115.png as it was blurry.
# Deleted image4_00019.png as it was blurry.
# Deleted image4_00025.png as it was blurry.
# Deleted image3_00082.png as it was blurry.
# Deleted image4_00031.png as it was blurry.
# Deleted image1_00162.png as it was blurry.
# Deleted image3_00069.png as it was blurry.
# Deleted image3_00041.png as it was blurry.
# Deleted image3_00055.png as it was blurry.
# Deleted image0_00049.png as it was blurry.
# Deleted image0_00061.png as it was blurry.
# Deleted image0_00060.png as it was blurry.
# Deleted image0_00048.png as it was blurry.
# Deleted image3_00054.png as it was blurry.
# Deleted image3_00040.png as it was blurry.
# Deleted image3_00068.png as it was blurry.
# Deleted image1_00163.png as it was blurry.
# Deleted image4_00030.png as it was blurry.
# Deleted image3_00083.png as it was blurry.
# Deleted image4_00024.png as it was blurry.
# Deleted image4_00018.png as it was blurry.
# Deleted image0_00114.png as it was blurry.
# Deleted image0_00100.png as it was blurry.
# Deleted image0_00128.png as it was blurry.
# Deleted image2_00037.png as it was blurry.
# Deleted image2_00023.png as it was blurry.
# Deleted image0_00104.png as it was blurry.
# Deleted image0_00110.png as it was blurry.
# Deleted image2_00027.png as it was blurry.
# Deleted image2_00033.png as it was blurry.
# Deleted image4_00020.png as it was blurry.
# Deleted image4_00034.png as it was blurry.
# Deleted image4_00008.png as it was blurry.
# Deleted image3_00044.png as it was blurry.
# Deleted image3_00078.png as it was blurry.
# Deleted image3_00079.png as it was blurry.
# Deleted image1_00166.png as it was blurry.
# Deleted image3_00045.png as it was blurry.
# Deleted image4_00009.png as it was blurry.
# Deleted image4_00035.png as it was blurry.
# Deleted image4_00021.png as it was blurry.
# Deleted image1_00012.png as it was blurry.
# Deleted image2_00032.png as it was blurry.
# Deleted image2_00026.png as it was blurry.
# Deleted image0_00111.png as it was blurry.
# Deleted image0_00105.png as it was blurry.
# Deleted image0_00113.png as it was blurry.
# Deleted image2_00018.png as it was blurry.
# Deleted image2_00030.png as it was blurry.
# Deleted image2_00024.png as it was blurry.
# Deleted image4_00023.png as it was blurry.
# Deleted image3_00084.png as it was blurry.
# Deleted image1_00158.png as it was blurry.
# Deleted image3_00047.png as it was blurry.
# Deleted image0_00098.png as it was blurry.
# Deleted image0_00099.png as it was blurry.
# Deleted image1_00165.png as it was blurry.
# Deleted image1_00171.png as it was blurry.
# Deleted image1_00159.png as it was blurry.
# Deleted image3_00046.png as it was blurry.
# Deleted image3_00085.png as it was blurry.
# Deleted image4_00022.png as it was blurry.
# Deleted image4_00036.png as it was blurry.
# Deleted image1_00039.png as it was blurry.
# Deleted image2_00025.png as it was blurry.
# Deleted image2_00031.png as it was blurry.
# Deleted image2_00019.png as it was blurry.
# Deleted image0_00112.png as it was blurry.
# Deleted image2_00028.png as it was blurry.
# Deleted image0_00123.png as it was blurry.
# Deleted image1_00034.png as it was blurry.
# Deleted image4_00013.png as it was blurry.
# Deleted image4_00007.png as it was blurry.
# Deleted image1_00154.png as it was blurry.
# Deleted image1_00168.png as it was blurry.
# Deleted image3_00077.png as it was blurry.
# Deleted image3_00063.png as it was blurry.
# Deleted image0_00094.png as it was blurry.
# Deleted image0_00043.png as it was blurry.
# Deleted image0_00042.png as it was blurry.
# Deleted image0_00095.png as it was blurry.
# Deleted image0_00081.png as it was blurry.
# Deleted image3_00062.png as it was blurry.
# Deleted image1_00169.png as it was blurry.
# Deleted image3_00076.png as it was blurry.
# Deleted image1_00141.png as it was blurry.
# Deleted image1_00155.png as it was blurry.
# Deleted image4_00006.png as it was blurry.
# Deleted image4_00012.png as it was blurry.
# Deleted image1_00035.png as it was blurry.
# Deleted image1_00021.png as it was blurry.
# Deleted image0_00122.png as it was blurry.
# Deleted image2_00029.png as it was blurry.
# Deleted image2_00001.png as it was blurry.
# Deleted image2_00003.png as it was blurry.
# Deleted image2_00017.png as it was blurry.
# Deleted image0_00120.png as it was blurry.
# Deleted image1_00023.png as it was blurry.
# Deleted image4_00038.png as it was blurry.
# Deleted image4_00004.png as it was blurry.
# Deleted image4_00010.png as it was blurry.
# Deleted image1_00143.png as it was blurry.
# Deleted image1_00157.png as it was blurry.
# Deleted image3_00060.png as it was blurry.
# Deleted image3_00074.png as it was blurry.
# Deleted image0_00083.png as it was blurry.
# Deleted image0_00040.png as it was blurry.
# Deleted image0_00041.png as it was blurry.
# Deleted image0_00082.png as it was blurry.
# Deleted image0_00096.png as it was blurry.
# Deleted image3_00075.png as it was blurry.
# Deleted image3_00061.png as it was blurry.
# Deleted image1_00156.png as it was blurry.
# Deleted image1_00142.png as it was blurry.
# Deleted image4_00011.png as it was blurry.
# Deleted image4_00005.png as it was blurry.
# Deleted image4_00039.png as it was blurry.
# Deleted image1_00022.png as it was blurry.
# Deleted image1_00036.png as it was blurry.
# Deleted image0_00121.png as it was blurry.
# Deleted image2_00002.png as it was blurry.
# Deleted image0_00125.png as it was blurry.
# Deleted image0_00119.png as it was blurry.
# Deleted image1_00032.png as it was blurry.
# Deleted image1_00026.png as it was blurry.
# Deleted image4_00001.png as it was blurry.
# Deleted image4_00015.png as it was blurry.
# Deleted image4_00029.png as it was blurry.
# Deleted image3_00065.png as it was blurry.
# Deleted image3_00071.png as it was blurry.
# Deleted image3_00059.png as it was blurry.
# Deleted image1_00146.png as it was blurry.
# Deleted image0_00092.png as it was blurry.
# Deleted image0_00086.png as it was blurry.
# Deleted image0_00045.png as it was blurry.
# Deleted image0_00079.png as it was blurry.
# Deleted image0_00078.png as it was blurry.
# Deleted image0_00044.png as it was blurry.
# Deleted image0_00050.png as it was blurry.
# Deleted image0_00087.png as it was blurry.
# Deleted image0_00093.png as it was blurry.
# Deleted image1_00153.png as it was blurry.
# Deleted image3_00058.png as it was blurry.
# Deleted image1_00147.png as it was blurry.
# Deleted image3_00070.png as it was blurry.
# Deleted image3_00064.png as it was blurry.
# Deleted image4_00028.png as it was blurry.
# Deleted image4_00014.png as it was blurry.
# Deleted image1_00027.png as it was blurry.
# Deleted image1_00033.png as it was blurry.
# Deleted image0_00118.png as it was blurry.
# Deleted image0_00124.png as it was blurry.
# Deleted image2_00039.png as it was blurry.
# Deleted image0_00126.png as it was blurry.
# Deleted image2_00005.png as it was blurry.
# Deleted image1_00019.png as it was blurry.
# Deleted image1_00031.png as it was blurry.
# Deleted image4_00016.png as it was blurry.
# Deleted image4_00002.png as it was blurry.
# Deleted image3_00072.png as it was blurry.
# Deleted image3_00066.png as it was blurry.
# Deleted image1_00145.png as it was blurry.
# Deleted image0_00085.png as it was blurry.
# Deleted image0_00091.png as it was blurry.
# Deleted image0_00046.png as it was blurry.
# Deleted image0_00047.png as it was blurry.
# Deleted image0_00090.png as it was blurry.
# Deleted image0_00084.png as it was blurry.
# Deleted image1_00144.png as it was blurry.
# Deleted image1_00178.png as it was blurry.
# Deleted image3_00067.png as it was blurry.
# Deleted image3_00073.png as it was blurry.
# Deleted image4_00003.png as it was blurry.
# Deleted image4_00017.png as it was blurry.
# Deleted image1_00030.png as it was blurry.
# Deleted image1_00024.png as it was blurry.
# Deleted image1_00018.png as it was blurry.
# Deleted image2_00004.png as it was blurry.
# Deleted image2_00038.png as it was blurry.
# Deleted image0_00127.png as it was blurry.
# Deleted image2_00088.png as it was blurry.
# Deleted image2_00077.png as it was blurry.
# Deleted image1_00043.png as it was blurry.
# Deleted image1_00057.png as it was blurry.
# Deleted image4_00058.png as it was blurry.
# Deleted image4_00070.png as it was blurry.
# Deleted image4_00064.png as it was blurry.
# Deleted image3_00028.png as it was blurry.
# Deleted image1_00123.png as it was blurry.
# Deleted image3_00014.png as it was blurry.
# Deleted image2_00103.png as it was blurry.
# Deleted image0_00020.png as it was blurry.
# Deleted image0_00034.png as it was blurry.
# Deleted image0_00035.png as it was blurry.
# Deleted image0_00021.png as it was blurry.
# Deleted image2_00102.png as it was blurry.
# Deleted image3_00015.png as it was blurry.
# Deleted image1_00122.png as it was blurry.
# Deleted image3_00029.png as it was blurry.
# Deleted image4_00065.png as it was blurry.
# Deleted image4_00071.png as it was blurry.
# Deleted image4_00059.png as it was blurry.
# Deleted image1_00056.png as it was blurry.
# Deleted image1_00042.png as it was blurry.
# Deleted image2_00076.png as it was blurry.
# Deleted image2_00089.png as it was blurry.
# Deleted image2_00074.png as it was blurry.
# Deleted image2_00048.png as it was blurry.
# Deleted image1_00054.png as it was blurry.
# Deleted image1_00068.png as it was blurry.
# Deleted image4_00067.png as it was blurry.
# Deleted image4_00073.png as it was blurry.
# Deleted image1_00120.png as it was blurry.
# Deleted image3_00003.png as it was blurry.
# Deleted image1_00108.png as it was blurry.
# Deleted image3_00017.png as it was blurry.
# Deleted image2_00114.png as it was blurry.
# Deleted image0_00037.png as it was blurry.
# Deleted image0_00023.png as it was blurry.
# Deleted image0_00022.png as it was blurry.
# Deleted image0_00036.png as it was blurry.
# Deleted image2_00101.png as it was blurry.
# Deleted image2_00115.png as it was blurry.
# Deleted image1_00109.png as it was blurry.
# Deleted image3_00016.png as it was blurry.
# Deleted image3_00002.png as it was blurry.
# Deleted image1_00121.png as it was blurry.
# Deleted image4_00072.png as it was blurry.
# Deleted image4_00066.png as it was blurry.
# Deleted image1_00069.png as it was blurry.
# Deleted image1_00041.png as it was blurry.
# Deleted image1_00055.png as it was blurry.
# Deleted image2_00049.png as it was blurry.
# Deleted image2_00075.png as it was blurry.
# Deleted image2_00065.png as it was blurry.
# Deleted image2_00071.png as it was blurry.
# Deleted image1_00051.png as it was blurry.
# Deleted image1_00045.png as it was blurry.
# Deleted image4_00062.png as it was blurry.
# Deleted image1_00119.png as it was blurry.
# Deleted image3_00006.png as it was blurry.
# Deleted image3_00012.png as it was blurry.
# Deleted image1_00125.png as it was blurry.
# Deleted image1_00131.png as it was blurry.
# Deleted image0_00032.png as it was blurry.
# Deleted image0_00026.png as it was blurry.
# Deleted image2_00105.png as it was blurry.
# Deleted image2_00104.png as it was blurry.
# Deleted image0_00033.png as it was blurry.
# Deleted image1_00130.png as it was blurry.
# Deleted image1_00124.png as it was blurry.
# Deleted image1_00118.png as it was blurry.
# Deleted image3_00007.png as it was blurry.
# Deleted image4_00063.png as it was blurry.
# Deleted image1_00044.png as it was blurry.
# Deleted image1_00050.png as it was blurry.
# Deleted image2_00070.png as it was blurry.
# Deleted image2_00072.png as it was blurry.
# Deleted image1_00046.png as it was blurry.
# Deleted image1_00052.png as it was blurry.
# Deleted image4_00061.png as it was blurry.
# Deleted image4_00049.png as it was blurry.
# Deleted image3_00011.png as it was blurry.
# Deleted image3_00005.png as it was blurry.
# Deleted image1_00132.png as it was blurry.
# Deleted image3_00039.png as it was blurry.
# Deleted image1_00126.png as it was blurry.
# Deleted image0_00025.png as it was blurry.
# Deleted image0_00031.png as it was blurry.
# Deleted image2_00112.png as it was blurry.
# Deleted image2_00113.png as it was blurry.
# Deleted image2_00107.png as it was blurry.
# Deleted image0_00030.png as it was blurry.
# Deleted image0_00024.png as it was blurry.
# Deleted image3_00038.png as it was blurry.
# Deleted image1_00127.png as it was blurry.
# Deleted image1_00133.png as it was blurry.
# Deleted image3_00004.png as it was blurry.
# Deleted image3_00010.png as it was blurry.
# Deleted image4_00048.png as it was blurry.
# Deleted image4_00060.png as it was blurry.
# Deleted image4_00074.png as it was blurry.
# Deleted image1_00053.png as it was blurry.
# Deleted image1_00047.png as it was blurry.
# Deleted image2_00073.png as it was blurry.

# %%
images = glob.glob("./working/tmp_input/*.png")
print("Found " + str(len(images)) + " images.")
# Out:
# Found 191 images.

# %%
# !rm -rf ./working/input
# !mkdir ./working/input

images = glob.glob("./working/tmp_input/*.png")

# Maximum number of images to copy
M = 100
step = len(images) // M

for i, image in enumerate(images):
	if i % step == 0:
		shutil.copy(image, f"./working/input/{i:05d}.png")
images = glob.glob("./working/input/*.png")
print(f"There are {len(images)} images in the working directory.")
# Out:
# There are 191 images in the working directory.

# %%
# !zip -r ./working/input.zip ./working/input
# Out:
#   adding: working/input/ (stored 0%)
#   adding: working/input/00126.png (deflated 0%)
#   adding: working/input/00132.png (deflated 0%)
#   adding: working/input/00091.png (deflated 0%)
#   adding: working/input/00085.png (deflated 0%)
#   adding: working/input/00052.png (deflated 0%)
#   adding: working/input/00046.png (deflated 0%)
#   adding: working/input/00047.png (deflated 0%)
#   adding: working/input/00053.png (deflated 0%)
#   adding: working/input/00084.png (deflated 0%)
#   adding: working/input/00090.png (deflated 0%)
#   adding: working/input/00133.png (deflated 0%)
#   adding: working/input/00127.png (deflated 0%)
#   adding: working/input/00131.png (deflated 0%)
#   adding: working/input/00125.png (deflated 0%)
#   adding: working/input/00119.png (deflated 0%)
#   adding: working/input/00086.png (deflated 0%)
#   adding: working/input/00092.png (deflated 0%)
#   adding: working/input/00045.png (deflated 0%)
#   adding: working/input/00051.png (deflated 0%)
#   adding: working/input/00079.png (deflated 0%)
#   adding: working/input/00078.png (deflated 0%)
#   adding: working/input/00050.png (deflated 0%)
#   adding: working/input/00044.png (deflated 0%)
#   adding: working/input/00093.png (deflated 0%)
#   adding: working/input/00087.png (deflated 0%)
#   adding: working/input/00118.png (deflated 0%)
#   adding: working/input/00124.png (deflated 0%)
#   adding: working/input/00130.png (deflated 0%)
#   adding: working/input/00108.png (deflated 0%)
#   adding: working/input/00134.png (deflated 0%)
#   adding: working/input/00120.png (deflated 0%)
#   adding: working/input/00083.png (deflated 0%)
#   adding: working/input/00097.png (deflated 0%)
#   adding: working/input/00068.png (deflated 0%)
#   adding: working/input/00040.png (deflated 0%)
#   adding: working/input/00054.png (deflated 0%)
#   adding: working/input/00055.png (deflated 0%)
#   adding: working/input/00041.png (deflated 0%)
#   adding: working/input/00069.png (deflated 0%)
#   adding: working/input/00096.png (deflated 0%)
#   adding: working/input/00082.png (deflated 0%)
#   adding: working/input/00121.png (deflated 0%)
#   adding: working/input/00135.png (deflated 0%)
#   adding: working/input/00109.png (deflated 0%)
#   adding: working/input/00123.png (deflated 0%)
#   adding: working/input/00137.png (deflated 0%)
#   adding: working/input/00094.png (deflated 0%)
#   adding: working/input/00080.png (deflated 0%)
#   adding: working/input/00057.png (deflated 0%)
#   adding: working/input/00043.png (deflated 0%)
#   adding: working/input/00042.png (deflated 0%)
#   adding: working/input/00056.png (deflated 0%)
#   adding: working/input/00081.png (deflated 0%)
#   adding: working/input/00095.png (deflated 0%)
#   adding: working/input/00136.png (deflated 0%)
#   adding: working/input/00122.png (deflated 0%)
#   adding: working/input/00186.png (deflated 0%)
#   adding: working/input/00145.png (deflated 0%)
#   adding: working/input/00151.png (deflated 0%)
#   adding: working/input/00179.png (deflated 0%)
#   adding: working/input/00031.png (deflated 0%)
#   adding: working/input/00025.png (deflated 0%)
#   adding: working/input/00019.png (deflated 0%)
#   adding: working/input/00018.png (deflated 0%)
#   adding: working/input/00024.png (deflated 0%)
#   adding: working/input/00030.png (deflated 0%)
#   adding: working/input/00178.png (deflated 0%)
#   adding: working/input/00150.png (deflated 0%)
#   adding: working/input/00144.png (deflated 0%)
#   adding: working/input/00187.png (deflated 0%)
#   adding: working/input/00185.png (deflated 0%)
#   adding: working/input/00152.png (deflated 0%)
#   adding: working/input/00146.png (deflated 0%)
#   adding: working/input/00026.png (deflated 0%)
#   adding: working/input/00032.png (deflated 0%)
#   adding: working/input/00033.png (deflated 0%)
#   adding: working/input/00027.png (deflated 0%)
#   adding: working/input/00147.png (deflated 0%)
#   adding: working/input/00153.png (deflated 0%)
#   adding: working/input/00184.png (deflated 0%)
#   adding: working/input/00190.png (deflated 0%)
#   adding: working/input/00180.png (deflated 0%)
#   adding: working/input/00157.png (deflated 0%)
#   adding: working/input/00143.png (deflated 0%)
#   adding: working/input/00023.png (deflated 0%)
#   adding: working/input/00037.png (deflated 0%)
#   adding: working/input/00036.png (deflated 0%)
#   adding: working/input/00022.png (deflated 0%)
#   adding: working/input/00142.png (deflated 0%)
#   adding: working/input/00156.png (deflated 0%)
#   adding: working/input/00181.png (deflated 0%)
#   adding: working/input/00183.png (deflated 0%)
#   adding: working/input/00168.png (deflated 0%)
#   adding: working/input/00140.png (deflated 0%)
#   adding: working/input/00154.png (deflated 0%)
#   adding: working/input/00008.png (deflated 0%)
#   adding: working/input/00034.png (deflated 0%)
#   adding: working/input/00020.png (deflated 0%)
#   adding: working/input/00021.png (deflated 0%)
#   adding: working/input/00035.png (deflated 0%)
#   adding: working/input/00009.png (deflated 0%)
#   adding: working/input/00155.png (deflated 0%)
#   adding: working/input/00141.png (deflated 0%)
#   adding: working/input/00169.png (deflated 0%)
#   adding: working/input/00182.png (deflated 0%)
#   adding: working/input/00164.png (deflated 0%)
#   adding: working/input/00170.png (deflated 0%)
#   adding: working/input/00158.png (deflated 0%)
#   adding: working/input/00010.png (deflated 0%)
#   adding: working/input/00004.png (deflated 0%)
#   adding: working/input/00038.png (deflated 0%)
#   adding: working/input/00039.png (deflated 0%)
#   adding: working/input/00005.png (deflated 0%)
#   adding: working/input/00011.png (deflated 0%)
#   adding: working/input/00159.png (deflated 0%)
#   adding: working/input/00171.png (deflated 0%)
#   adding: working/input/00165.png (deflated 0%)
#   adding: working/input/00173.png (deflated 0%)
#   adding: working/input/00167.png (deflated 0%)
#   adding: working/input/00007.png (deflated 0%)
#   adding: working/input/00013.png (deflated 0%)
#   adding: working/input/00012.png (deflated 0%)
#   adding: working/input/00006.png (deflated 0%)
#   adding: working/input/00166.png (deflated 0%)
#   adding: working/input/00172.png (deflated 0%)
#   adding: working/input/00189.png (deflated 0%)
#   adding: working/input/00176.png (deflated 0%)
#   adding: working/input/00162.png (deflated 0%)
#   adding: working/input/00002.png (deflated 0%)
#   adding: working/input/00016.png (deflated 0%)
#   adding: working/input/00017.png (deflated 0%)
#   adding: working/input/00003.png (deflated 0%)
#   adding: working/input/00163.png (deflated 0%)
#   adding: working/input/00177.png (deflated 0%)
#   adding: working/input/00188.png (deflated 0%)
#   adding: working/input/00149.png (deflated 0%)
#   adding: working/input/00161.png (deflated 0%)
#   adding: working/input/00175.png (deflated 0%)
#   adding: working/input/00029.png (deflated 0%)
#   adding: working/input/00015.png (deflated 0%)
#   adding: working/input/00001.png (deflated 0%)
#   adding: working/input/00000.png (deflated 0%)
#   adding: working/input/00014.png (deflated 0%)
#   adding: working/input/00028.png (deflated 0%)
#   adding: working/input/00174.png (deflated 0%)
#   adding: working/input/00160.png (deflated 0%)
#   adding: working/input/00148.png (deflated 0%)
#   adding: working/input/00107.png (deflated 0%)
#   adding: working/input/00113.png (deflated 0%)
#   adding: working/input/00098.png (deflated 0%)
#   adding: working/input/00073.png (deflated 0%)
#   adding: working/input/00067.png (deflated 0%)
#   adding: working/input/00066.png (deflated 0%)
#   adding: working/input/00072.png (deflated 0%)
#   adding: working/input/00099.png (deflated 0%)
#   adding: working/input/00112.png (deflated 0%)
#   adding: working/input/00106.png (deflated 0%)
#   adding: working/input/00110.png (deflated 0%)
#   adding: working/input/00104.png (deflated 0%)
#   adding: working/input/00138.png (deflated 0%)
#   adding: working/input/00064.png (deflated 0%)
#   adding: working/input/00070.png (deflated 0%)
#   adding: working/input/00058.png (deflated 0%)
#   adding: working/input/00059.png (deflated 0%)
#   adding: working/input/00071.png (deflated 0%)
#   adding: working/input/00065.png (deflated 0%)
#   adding: working/input/00139.png (deflated 0%)
#   adding: working/input/00105.png (deflated 0%)
#   adding: working/input/00111.png (deflated 0%)
#   adding: working/input/00129.png (deflated 0%)
#   adding: working/input/00115.png (deflated 0%)
#   adding: working/input/00101.png (deflated 0%)
#   adding: working/input/00049.png (deflated 0%)
#   adding: working/input/00061.png (deflated 0%)
#   adding: working/input/00075.png (deflated 0%)
#   adding: working/input/00074.png (deflated 0%)
#   adding: working/input/00060.png (deflated 0%)
#   adding: working/input/00048.png (deflated 0%)
#   adding: working/input/00100.png (deflated 0%)
#   adding: working/input/00114.png (deflated 0%)
#   adding: working/input/00128.png (deflated 0%)
#   adding: working/input/00102.png (deflated 0%)
#   adding: working/input/00116.png (deflated 0%)
#   adding: working/input/00089.png (deflated 0%)
#   adding: working/input/00076.png (deflated 0%)
#   adding: working/input/00062.png (deflated 0%)
#   adding: working/input/00063.png (deflated 0%)
#   adding: working/input/00077.png (deflated 0%)
#   adding: working/input/00088.png (deflated 0%)
#   adding: working/input/00117.png (deflated 0%)
#   adding: working/input/00103.png (deflated 0%)
